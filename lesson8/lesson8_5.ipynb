# %%
def say_hello():
    print("Hello! , 您好")

say_hello()
# Out:
# Hello! , 您好

# %%
def say_hello(name):
    print(f"Hello, {name} ! , 您好")

say_hello("TOM")
# Out:
# Hello, TOM ! , 您好

# %%
def say_hello(name:str)->str:
    return (f"Hello, {name} !,Good day , 您好")

print say_hello("TOM")
# Out:
# Hello, TOM !,Good day , 您好
